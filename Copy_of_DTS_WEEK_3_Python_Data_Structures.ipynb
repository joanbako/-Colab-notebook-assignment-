# %% [markdown]
# <a href="https://colab.research.google.com/github/joanbako/-Colab-notebook-assignment-/blob/main/Copy_of_DTS_WEEK_3_Python_Data_Structures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ASSIGNMENT (Week 3)
#
# Submit your Jupyter Notebook (.ipynb) through your GitHub repository.

# %% [markdown]
# # ASSIGNMENT 1. Create a list of 5 student scores

# %%
scores = [90,70,50,30,10]
print(scores)
# Out:
# [90, 70, 50, 30, 10]

# %% [markdown]
# # ASSIGNMENT 2. Compute the average score

# %%
total = 0
for score in scores:
    total = total + score

average = total / len(scores)
print("Average score:", average)
# Out:
# Average score: 50.0

# %% [markdown]
# # ASSIGNMENT 3. Find the highest score

# %%
highest = scores[0]
for score in scores:
    if score > highest:
        highest = score

print("Highest score:", highest)
# Out:
# Highest score: 90

# %% [markdown]
# # ASSIGNMENT 4. Create a dictionary with 5 students and scores

# %%
students = {
    "S001": 90,
    "S002": 70,
    "S003": 50,
    "S004": 30,
}

print(students)
# Out:
# {'S001': 90, 'S002': 70, 'S003': 50, 'S004': 30}

# %% [markdown]
# # ASSIGNMENT 5. Find the highest scoring student

# %%
highest_id = None
highest_score = 0

for student_id in students:
    score = students[student_id]

    if score > highest_score:
        highest_score = score
        highest_id = student_id

print("Highest scoring student:", highest_id)
print("Score:", highest_score)
# Out:
# Highest scoring student: S001
# Score: 90

# %% [markdown]
# # ASSIGNMENT 6. Create a tuple of subjects

# %%
subjects = ("Math", "English", "Science")
print(subjects)
print(subjects[0])
# Out:
# ('Math', 'English', 'Science')
# Math

# %% [markdown]
# # ASSIGNMENT 7. Create a set of unique scores

# %%
scores_set = {90,80,70,60,50}
print(scores_set)
# Out:
# {80, 50, 70, 90, 60}

# %% [markdown]
# Name Wukden Joan Bako
# Mat num 202550651835JA
# Course D T S assignment
# Dept Data science
# Faculty computing
